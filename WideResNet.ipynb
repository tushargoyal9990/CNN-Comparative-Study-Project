# %% [markdown]
# **Loading the dataset**

# %%
from google.colab import drive
drive.mount('/content/gdrive')
 
# %cd gdrive/My Drive/Project
 
import cifar10
 
cifar10.data_path = "data/CIFAR-10/"
cifar10.maybe_download_and_extract()
 
class_names = cifar10.load_class_names()
images_train, cls_train, labels_train= cifar10.load_training_data()
images_test, cls_test, labels_test = cifar10.load_test_data()
 
x_train = images_train[0:45000]
y_train = labels_train[0:45000]
 
 
x_valid = images_train[45000:50000]
y_valid = labels_train[45000:50000]
 
x_test = images_test
y_test = labels_test
# Out:
# Mounted at /content/gdrive
# /content/gdrive/My Drive/Project
# Data has apparently already been downloaded and unpacked.
# Loading data: data/CIFAR-10/cifar-10-batches-py/batches.meta
# Loading data: data/CIFAR-10/cifar-10-batches-py/data_batch_1
# Loading data: data/CIFAR-10/cifar-10-batches-py/data_batch_2
# Loading data: data/CIFAR-10/cifar-10-batches-py/data_batch_3
# Loading data: data/CIFAR-10/cifar-10-batches-py/data_batch_4
# Loading data: data/CIFAR-10/cifar-10-batches-py/data_batch_5
# Loading data: data/CIFAR-10/cifar-10-batches-py/test_batch

# %% [markdown]
# **Import Statements**

# %%
from keras.models import load_model, Model
from keras.optimizers import Adam
from keras.initializers import glorot_uniform
from keras.layers import Conv2D, Dense, Flatten, BatchNormalization, Input, Activation, Add, Dropout, AveragePooling2D
from sklearn.metrics import classification_report, accuracy_score, confusion_matrix
import time
import pickle
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %% [markdown]
# **Building the Model**

# %%
def convolutional_block(X, f, s):
 
  X_shortcut = X
 
  X = Conv2D(f * 8, (3,3), strides = (s,s), padding = 'same', activation = 'relu', kernel_initializer = glorot_uniform(seed = 0))(X)
  X = Dropout(0.25)(X)
  X = Conv2D(f * 8, (3,3), strides = (1,1), padding = 'same', activation = 'relu', kernel_initializer = glorot_uniform(seed = 0))(X)
 
  X_shortcut = Conv2D(f * 8, (1,1), strides = (s,s), padding = 'same', activation = 'relu', kernel_initializer = glorot_uniform(seed = 0))(X_shortcut)
 
  X = Add()([X, X_shortcut])
  return X

# %%
def WideResNet():
 
  X_input = Input((32,32,3)) 
 
  X = Conv2D(16, (3,3), activation = 'relu', padding = "same", kernel_initializer = glorot_uniform(seed = 0))(X_input)
  X = BatchNormalization()(X)  
 
  X = convolutional_block(X, 16, 1) 
  X = convolutional_block(X, 16, 1)   
  X = convolutional_block(X, 16, 1)   
 
  X = convolutional_block(X, 32, 2)
  X = convolutional_block(X, 32, 1)   
  X = convolutional_block(X, 32, 1)   
 
  X = convolutional_block(X, 64, 2)
  X = convolutional_block(X, 64, 1)   
  X = convolutional_block(X, 64, 1)    
 
  X = AveragePooling2D((8,8))(X)
 
  X = Flatten()(X)
  X = Dense(10, activation = 'softmax', kernel_initializer = glorot_uniform(seed = 0))(X)
 
  model = Model(inputs = X_input, outputs = X)
 
  return model

# %%
model = WideResNet()
model.summary()
# Out:
# Model: "functional_3"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_2 (InputLayer)            [(None, 32, 32, 3)]  0
# __________________________________________________________________________________________________
# conv2d_28 (Conv2D)              (None, 32, 32, 16)   448         input_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 32, 32, 16)   64          conv2d_28[0][0]
# __________________________________________________________________________________________________
# conv2d_29 (Conv2D)              (None, 32, 32, 128)  18560       batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# dropout_9 (Dropout)             (None, 32, 32, 128)  0           conv2d_29[0][0]
# __________________________________________________________________________________________________
# conv2d_30 (Conv2D)              (None, 32, 32, 128)  147584      dropout_9[0][0]
# __________________________________________________________________________________________________
# conv2d_31 (Conv2D)              (None, 32, 32, 128)  2176        batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# add_9 (Add)                     (None, 32, 32, 128)  0           conv2d_30[0][0]
#                                                                  conv2d_31[0][0]
# __________________________________________________________________________________________________
# conv2d_32 (Conv2D)              (None, 32, 32, 128)  147584      add_9[0][0]
# __________________________________________________________________________________________________
# dropout_10 (Dropout)            (None, 32, 32, 128)  0           conv2d_32[0][0]
# __________________________________________________________________________________________________
# conv2d_33 (Conv2D)              (None, 32, 32, 128)  147584      dropout_10[0][0]
# __________________________________________________________________________________________________
# conv2d_34 (Conv2D)              (None, 32, 32, 128)  16512       add_9[0][0]
# __________________________________________________________________________________________________
# add_10 (Add)                    (None, 32, 32, 128)  0           conv2d_33[0][0]
#                                                                  conv2d_34[0][0]
# __________________________________________________________________________________________________
# conv2d_35 (Conv2D)              (None, 32, 32, 128)  147584      add_10[0][0]
# __________________________________________________________________________________________________
# dropout_11 (Dropout)            (None, 32, 32, 128)  0           conv2d_35[0][0]
# __________________________________________________________________________________________________
# conv2d_36 (Conv2D)              (None, 32, 32, 128)  147584      dropout_11[0][0]
# __________________________________________________________________________________________________
# conv2d_37 (Conv2D)              (None, 32, 32, 128)  16512       add_10[0][0]
# __________________________________________________________________________________________________
# add_11 (Add)                    (None, 32, 32, 128)  0           conv2d_36[0][0]
#                                                                  conv2d_37[0][0]
# __________________________________________________________________________________________________
# conv2d_38 (Conv2D)              (None, 16, 16, 256)  295168      add_11[0][0]
# __________________________________________________________________________________________________
# dropout_12 (Dropout)            (None, 16, 16, 256)  0           conv2d_38[0][0]
# __________________________________________________________________________________________________
# conv2d_39 (Conv2D)              (None, 16, 16, 256)  590080      dropout_12[0][0]
# __________________________________________________________________________________________________
# conv2d_40 (Conv2D)              (None, 16, 16, 256)  33024       add_11[0][0]
# __________________________________________________________________________________________________
# add_12 (Add)                    (None, 16, 16, 256)  0           conv2d_39[0][0]
#                                                                  conv2d_40[0][0]
# __________________________________________________________________________________________________
# conv2d_41 (Conv2D)              (None, 16, 16, 256)  590080      add_12[0][0]
# __________________________________________________________________________________________________
# dropout_13 (Dropout)            (None, 16, 16, 256)  0           conv2d_41[0][0]
# __________________________________________________________________________________________________
# conv2d_42 (Conv2D)              (None, 16, 16, 256)  590080      dropout_13[0][0]
# __________________________________________________________________________________________________
# conv2d_43 (Conv2D)              (None, 16, 16, 256)  65792       add_12[0][0]
# __________________________________________________________________________________________________
# add_13 (Add)                    (None, 16, 16, 256)  0           conv2d_42[0][0]
#                                                                  conv2d_43[0][0]
# __________________________________________________________________________________________________
# conv2d_44 (Conv2D)              (None, 16, 16, 256)  590080      add_13[0][0]
# __________________________________________________________________________________________________
# dropout_14 (Dropout)            (None, 16, 16, 256)  0           conv2d_44[0][0]
# __________________________________________________________________________________________________
# conv2d_45 (Conv2D)              (None, 16, 16, 256)  590080      dropout_14[0][0]
# __________________________________________________________________________________________________
# conv2d_46 (Conv2D)              (None, 16, 16, 256)  65792       add_13[0][0]
# __________________________________________________________________________________________________
# add_14 (Add)                    (None, 16, 16, 256)  0           conv2d_45[0][0]
#                                                                  conv2d_46[0][0]
# __________________________________________________________________________________________________
# conv2d_47 (Conv2D)              (None, 8, 8, 512)    1180160     add_14[0][0]
# __________________________________________________________________________________________________
# dropout_15 (Dropout)            (None, 8, 8, 512)    0           conv2d_47[0][0]
# __________________________________________________________________________________________________
# conv2d_48 (Conv2D)              (None, 8, 8, 512)    2359808     dropout_15[0][0]
# __________________________________________________________________________________________________
# conv2d_49 (Conv2D)              (None, 8, 8, 512)    131584      add_14[0][0]
# __________________________________________________________________________________________________
# add_15 (Add)                    (None, 8, 8, 512)    0           conv2d_48[0][0]
#                                                                  conv2d_49[0][0]
# __________________________________________________________________________________________________
# conv2d_50 (Conv2D)              (None, 8, 8, 512)    2359808     add_15[0][0]
# __________________________________________________________________________________________________
# dropout_16 (Dropout)            (None, 8, 8, 512)    0           conv2d_50[0][0]
# __________________________________________________________________________________________________
# conv2d_51 (Conv2D)              (None, 8, 8, 512)    2359808     dropout_16[0][0]
# __________________________________________________________________________________________________
# conv2d_52 (Conv2D)              (None, 8, 8, 512)    262656      add_15[0][0]
# __________________________________________________________________________________________________
# add_16 (Add)                    (None, 8, 8, 512)    0           conv2d_51[0][0]
#                                                                  conv2d_52[0][0]
# __________________________________________________________________________________________________
# conv2d_53 (Conv2D)              (None, 8, 8, 512)    2359808     add_16[0][0]
# __________________________________________________________________________________________________
# dropout_17 (Dropout)            (None, 8, 8, 512)    0           conv2d_53[0][0]
# __________________________________________________________________________________________________
# conv2d_54 (Conv2D)              (None, 8, 8, 512)    2359808     dropout_17[0][0]
# __________________________________________________________________________________________________
# conv2d_55 (Conv2D)              (None, 8, 8, 512)    262656      add_16[0][0]
# __________________________________________________________________________________________________
# add_17 (Add)                    (None, 8, 8, 512)    0           conv2d_54[0][0]
#                                                                  conv2d_55[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_1 (AveragePoo (None, 1, 1, 512)    0           add_17[0][0]
# __________________________________________________________________________________________________
# flatten_1 (Flatten)             (None, 512)          0           average_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 10)           5130        flatten_1[0][0]
# ==================================================================================================
# Total params: 17,843,594
# Trainable params: 17,843,562
# Non-trainable params: 32
# __________________________________________________________________________________________________

# %% [markdown]
# **Training the Model**

# %%
model = WideResNet()
model.compile(loss = 'categorical_crossentropy', optimizer = Adam(learning_rate = 1.0e-4), metrics = ['accuracy'])
start = time.time()
model.fit(x_train, y_train, epochs = 1, batch_size = 100, validation_data = (x_valid, y_valid))
end = time.time()
# Out:
#   2/450 [..............................] - ETA: 59s - loss: 2.3790 - accuracy: 0.0950WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0128s vs `on_train_batch_end` time: 0.1227s). Check your callbacks.
# 450/450 [==============================] - ETA: 0s - loss: 1.8220 - accuracy: 0.3029WARNING:tensorflow:Callbacks method `on_test_batch_end` is slow compared to the batch time (batch time: 0.0028s vs `on_test_batch_end` time: 0.0380s). Check your callbacks.
# 450/450 [==============================] - 63s 139ms/step - loss: 1.8220 - accuracy: 0.3029 - val_loss: 1.6913 - val_accuracy: 0.4048

# %%
model = WideResNet()
model.compile(loss = 'categorical_crossentropy', optimizer = Adam(learning_rate = 1.0e-4), metrics = ['accuracy'])
history = model.fit(x_train, y_train,epochs = 120, batch_size = 100, validation_data = (x_valid, y_valid))
# Out:
# Epoch 1/120
#   2/450 [..............................] - ETA: 57s - loss: 2.4326 - accuracy: 0.0800WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0124s vs `on_train_batch_end` time: 0.1209s). Check your callbacks.
# 450/450 [==============================] - ETA: 0s - loss: 1.8192 - accuracy: 0.3069WARNING:tensorflow:Callbacks method `on_test_batch_end` is slow compared to the batch time (batch time: 0.0041s vs `on_test_batch_end` time: 0.0376s). Check your callbacks.
# 450/450 [==============================] - 62s 139ms/step - loss: 1.8192 - accuracy: 0.3069 - val_loss: 1.6831 - val_accuracy: 0.3976
# Epoch 2/120
# 450/450 [==============================] - 62s 138ms/step - loss: 1.4276 - accuracy: 0.4703 - val_loss: 1.2587 - val_accuracy: 0.5318
# Epoch 3/120
# 450/450 [==============================] - 62s 138ms/step - loss: 1.1975 - accuracy: 0.5632 - val_loss: 1.0781 - val_accuracy: 0.6072
# Epoch 4/120
# 450/450 [==============================] - 63s 139ms/step - loss: 1.0444 - accuracy: 0.6258 - val_loss: 0.9418 - val_accuracy: 0.6622
# Epoch 5/120
# 450/450 [==============================] - 62s 139ms/step - loss: 0.9209 - accuracy: 0.6714 - val_loss: 0.8949 - val_accuracy: 0.6868
# Epoch 6/120
# 450/450 [==============================] - 62s 139ms/step - loss: 0.8173 - accuracy: 0.7112 - val_loss: 0.8591 - val_accuracy: 0.6948
# Epoch 7/120
# 450/450 [==============================] - 62s 139ms/step - loss: 0.7338 - accuracy: 0.7405 - val_loss: 0.7519 - val_accuracy: 0.7326
# Epoch 8/120
# 450/450 [==============================] - 62s 139ms/step - loss: 0.6487 - accuracy: 0.7707 - val_loss: 0.6898 - val_accuracy: 0.7612
# Epoch 9/120
# 450/450 [==============================] - 62s 139ms/step - loss: 0.5783 - accuracy: 0.7974 - val_loss: 0.6611 - val_accuracy: 0.7744
# Epoch 10/120
# 450/450 [==============================] - 62s 139ms/step - loss: 0.5135 - accuracy: 0.8199 - val_loss: 0.6416 - val_accuracy: 0.7848
# Epoch 11/120
# 450/450 [==============================] - 62s 139ms/step - loss: 0.4672 - accuracy: 0.8353 - val_loss: 0.6329 - val_accuracy: 0.7826
# Epoch 12/120
# 450/450 [==============================] - 62s 139ms/step - loss: 0.4069 - accuracy: 0.8568 - val_loss: 0.5786 - val_accuracy: 0.8116
# Epoch 13/120
# 450/450 [==============================] - 62s 139ms/step - loss: 0.3549 - accuracy: 0.8751 - val_loss: 0.5808 - val_accuracy: 0.8098
# Epoch 14/120
# 450/450 [==============================] - 62s 139ms/step - loss: 0.3014 - accuracy: 0.8931 - val_loss: 0.6365 - val_accuracy: 0.7994
# Epoch 15/120
# 450/450 [==============================] - 62s 139ms/step - loss: 0.2611 - accuracy: 0.9080 - val_loss: 0.5819 - val_accuracy: 0.8188
# Epoch 16/120
# 450/450 [==============================] - 62s 139ms/step - loss: 0.2228 - accuracy: 0.9215 - val_loss: 0.6450 - val_accuracy: 0.8184
# Epoch 17/120
# 450/450 [==============================] - 62s 139ms/step - loss: 0.1840 - accuracy: 0.9352 - val_loss: 0.6929 - val_accuracy: 0.8168
# Epoch 18/120
# 450/450 [==============================] - 62s 139ms/step - loss: 0.1600 - accuracy: 0.9433 - val_loss: 0.6780 - val_accuracy: 0.8242
# Epoch 19/120
# 450/450 [==============================] - 62s 139ms/step - loss: 0.1348 - accuracy: 0.9524 - val_loss: 0.7446 - val_accuracy: 0.8104
# Epoch 20/120
# 450/450 [==============================] - 62s 139ms/step - loss: 0.1117 - accuracy: 0.9591 - val_loss: 0.8603 - val_accuracy: 0.8182
# Epoch 21/120
# 450/450 [==============================] - 62s 138ms/step - loss: 0.1024 - accuracy: 0.9634 - val_loss: 0.7737 - val_accuracy: 0.8110
# Epoch 22/120
# 450/450 [==============================] - 62s 138ms/step - loss: 0.0820 - accuracy: 0.9721 - val_loss: 0.8503 - val_accuracy: 0.8186
# Epoch 23/120
# 450/450 [==============================] - 62s 139ms/step - loss: 0.0755 - accuracy: 0.9738 - val_loss: 0.8117 - val_accuracy: 0.8126
# Epoch 24/120
# 450/450 [==============================] - 63s 139ms/step - loss: 0.0726 - accuracy: 0.9753 - val_loss: 0.8648 - val_accuracy: 0.8252
# Epoch 25/120
# 450/450 [==============================] - 63s 139ms/step - loss: 0.0626 - accuracy: 0.9777 - val_loss: 0.9294 - val_accuracy: 0.8182
# Epoch 26/120
# 450/450 [==============================] - 63s 139ms/step - loss: 0.0586 - accuracy: 0.9787 - val_loss: 0.8866 - val_accuracy: 0.8254
# Epoch 27/120
# 450/450 [==============================] - 63s 139ms/step - loss: 0.0547 - accuracy: 0.9812 - val_loss: 0.9055 - val_accuracy: 0.8106
# Epoch 28/120
# 450/450 [==============================] - 63s 139ms/step - loss: 0.0462 - accuracy: 0.9846 - val_loss: 0.8626 - val_accuracy: 0.8220
# Epoch 29/120
# 450/450 [==============================] - 63s 139ms/step - loss: 0.0526 - accuracy: 0.9818 - val_loss: 0.8576 - val_accuracy: 0.8170
# Epoch 30/120
# 450/450 [==============================] - 62s 139ms/step - loss: 0.0486 - accuracy: 0.9834 - val_loss: 0.8873 - val_accuracy: 0.8216
# Epoch 31/120
# 450/450 [==============================] - 62s 138ms/step - loss: 0.0428 - accuracy: 0.9851 - val_loss: 0.8857 - val_accuracy: 0.8290
# Epoch 32/120
# 450/450 [==============================] - 62s 138ms/step - loss: 0.0428 - accuracy: 0.9854 - val_loss: 0.9090 - val_accuracy: 0.8336
# Epoch 33/120
# 450/450 [==============================] - 62s 138ms/step - loss: 0.0426 - accuracy: 0.9864 - val_loss: 0.9401 - val_accuracy: 0.8224
# Epoch 34/120
# 450/450 [==============================] - 62s 138ms/step - loss: 0.0388 - accuracy: 0.9866 - val_loss: 0.8819 - val_accuracy: 0.8302
# Epoch 35/120
# 450/450 [==============================] - 62s 138ms/step - loss: 0.0347 - accuracy: 0.9889 - val_loss: 1.0929 - val_accuracy: 0.8224
# Epoch 36/120
# 450/450 [==============================] - 62s 138ms/step - loss: 0.0341 - accuracy: 0.9886 - val_loss: 0.9261 - val_accuracy: 0.8226
# Epoch 37/120
# 450/450 [==============================] - 62s 138ms/step - loss: 0.0365 - accuracy: 0.9878 - val_loss: 1.0546 - val_accuracy: 0.8124
# Epoch 38/120
# 450/450 [==============================] - 62s 138ms/step - loss: 0.0362 - accuracy: 0.9875 - val_loss: 0.9965 - val_accuracy: 0.8226
# Epoch 39/120
# 450/450 [==============================] - 62s 138ms/step - loss: 0.0336 - accuracy: 0.9882 - val_loss: 0.9401 - val_accuracy: 0.8264
# Epoch 40/120
# 450/450 [==============================] - 62s 138ms/step - loss: 0.0307 - accuracy: 0.9898 - val_loss: 1.0359 - val_accuracy: 0.8124
# Epoch 41/120
# 450/450 [==============================] - 62s 138ms/step - loss: 0.0333 - accuracy: 0.9894 - val_loss: 0.8371 - val_accuracy: 0.8204
# Epoch 42/120
# 450/450 [==============================] - 62s 138ms/step - loss: 0.0268 - accuracy: 0.9915 - val_loss: 0.9861 - val_accuracy: 0.8304
# Epoch 43/120
# 450/450 [==============================] - 62s 139ms/step - loss: 0.0278 - accuracy: 0.9907 - val_loss: 0.9709 - val_accuracy: 0.8360
# Epoch 44/120
# 450/450 [==============================] - 62s 138ms/step - loss: 0.0299 - accuracy: 0.9900 - val_loss: 0.9922 - val_accuracy: 0.8388
# Epoch 45/120
# 450/450 [==============================] - 62s 138ms/step - loss: 0.0270 - accuracy: 0.9908 - val_loss: 0.9847 - val_accuracy: 0.8274
# Epoch 46/120
# 450/450 [==============================] - 62s 139ms/step - loss: 0.0263 - accuracy: 0.9910 - val_loss: 1.1678 - val_accuracy: 0.8148
# Epoch 47/120
# 450/450 [==============================] - 62s 138ms/step - loss: 0.0264 - accuracy: 0.9909 - val_loss: 0.9957 - val_accuracy: 0.8176
# Epoch 48/120
# 450/450 [==============================] - 62s 138ms/step - loss: 0.0234 - accuracy: 0.9925 - val_loss: 1.0421 - val_accuracy: 0.8310
# Epoch 49/120
# 450/450 [==============================] - 62s 138ms/step - loss: 0.0247 - accuracy: 0.9921 - val_loss: 1.0617 - val_accuracy: 0.8318
# Epoch 50/120
# 450/450 [==============================] - 62s 138ms/step - loss: 0.0265 - accuracy: 0.9911 - val_loss: 0.9153 - val_accuracy: 0.8342
# Epoch 51/120
# 450/450 [==============================] - 62s 138ms/step - loss: 0.0263 - accuracy: 0.9912 - val_loss: 0.9468 - val_accuracy: 0.8372
# Epoch 52/120
# 450/450 [==============================] - 62s 138ms/step - loss: 0.0221 - accuracy: 0.9920 - val_loss: 0.9337 - val_accuracy: 0.8328
# Epoch 53/120
# 450/450 [==============================] - 62s 139ms/step - loss: 0.0222 - accuracy: 0.9925 - val_loss: 1.0172 - val_accuracy: 0.8338
# Epoch 54/120
# 450/450 [==============================] - 62s 138ms/step - loss: 0.0226 - accuracy: 0.9925 - val_loss: 0.9286 - val_accuracy: 0.8404
# Epoch 55/120
# 450/450 [==============================] - 62s 139ms/step - loss: 0.0256 - accuracy: 0.9915 - val_loss: 0.9264 - val_accuracy: 0.8332
# Epoch 56/120
# 450/450 [==============================] - 62s 138ms/step - loss: 0.0204 - accuracy: 0.9933 - val_loss: 0.9733 - val_accuracy: 0.8282
# Epoch 57/120
# 450/450 [==============================] - 62s 139ms/step - loss: 0.0214 - accuracy: 0.9928 - val_loss: 1.0107 - val_accuracy: 0.8324
# Epoch 58/120
# 450/450 [==============================] - 62s 139ms/step - loss: 0.0186 - accuracy: 0.9941 - val_loss: 1.0733 - val_accuracy: 0.8164
# Epoch 59/120
# 450/450 [==============================] - 62s 138ms/step - loss: 0.0214 - accuracy: 0.9928 - val_loss: 0.9645 - val_accuracy: 0.8340
# Epoch 60/120
# 450/450 [==============================] - 62s 138ms/step - loss: 0.0204 - accuracy: 0.9934 - val_loss: 0.9140 - val_accuracy: 0.8366
# Epoch 61/120
# 450/450 [==============================] - 62s 138ms/step - loss: 0.0204 - accuracy: 0.9936 - val_loss: 0.8989 - val_accuracy: 0.8350
# Epoch 62/120
# 450/450 [==============================] - 62s 139ms/step - loss: 0.0222 - accuracy: 0.9928 - val_loss: 0.8671 - val_accuracy: 0.8396
# Epoch 63/120
# 450/450 [==============================] - 62s 138ms/step - loss: 0.0179 - accuracy: 0.9945 - val_loss: 1.0571 - val_accuracy: 0.8288
# Epoch 64/120
# 450/450 [==============================] - 62s 138ms/step - loss: 0.0166 - accuracy: 0.9948 - val_loss: 1.1153 - val_accuracy: 0.8290
# Epoch 65/120
# 450/450 [==============================] - 62s 138ms/step - loss: 0.0198 - accuracy: 0.9936 - val_loss: 1.0041 - val_accuracy: 0.8322
# Epoch 66/120
# 450/450 [==============================] - 62s 138ms/step - loss: 0.0183 - accuracy: 0.9940 - val_loss: 0.9345 - val_accuracy: 0.8388
# Epoch 67/120
# 450/450 [==============================] - 62s 138ms/step - loss: 0.0140 - accuracy: 0.9950 - val_loss: 1.1584 - val_accuracy: 0.8256
# Epoch 68/120
# 450/450 [==============================] - 62s 138ms/step - loss: 0.0173 - accuracy: 0.9945 - val_loss: 1.1384 - val_accuracy: 0.8290
# Epoch 69/120
# 450/450 [==============================] - 62s 138ms/step - loss: 0.0198 - accuracy: 0.9936 - val_loss: 0.9838 - val_accuracy: 0.8390
# Epoch 70/120
# 450/450 [==============================] - 62s 138ms/step - loss: 0.0142 - accuracy: 0.9954 - val_loss: 1.0457 - val_accuracy: 0.8356
# Epoch 71/120
# 450/450 [==============================] - 62s 138ms/step - loss: 0.0227 - accuracy: 0.9928 - val_loss: 0.9443 - val_accuracy: 0.8362
# Epoch 72/120
# 450/450 [==============================] - 62s 138ms/step - loss: 0.0171 - accuracy: 0.9946 - val_loss: 0.8963 - val_accuracy: 0.8350
# Epoch 73/120
# 450/450 [==============================] - 62s 138ms/step - loss: 0.0143 - accuracy: 0.9956 - val_loss: 0.9984 - val_accuracy: 0.8388
# Epoch 74/120
# 450/450 [==============================] - 62s 138ms/step - loss: 0.0146 - accuracy: 0.9955 - val_loss: 1.1406 - val_accuracy: 0.8276
# Epoch 75/120
# 450/450 [==============================] - 62s 138ms/step - loss: 0.0171 - accuracy: 0.9943 - val_loss: 1.1681 - val_accuracy: 0.8374
# Epoch 76/120
# 450/450 [==============================] - 62s 138ms/step - loss: 0.0148 - accuracy: 0.9952 - val_loss: 1.0161 - val_accuracy: 0.8348
# Epoch 77/120
# 450/450 [==============================] - 62s 138ms/step - loss: 0.0161 - accuracy: 0.9948 - val_loss: 1.0266 - val_accuracy: 0.8340
# Epoch 78/120
# 450/450 [==============================] - 62s 138ms/step - loss: 0.0135 - accuracy: 0.9957 - val_loss: 0.9961 - val_accuracy: 0.8336
# Epoch 79/120
# 450/450 [==============================] - 62s 138ms/step - loss: 0.0186 - accuracy: 0.9942 - val_loss: 1.0992 - val_accuracy: 0.8410
# Epoch 80/120
# 450/450 [==============================] - 62s 138ms/step - loss: 0.0128 - accuracy: 0.9960 - val_loss: 1.0680 - val_accuracy: 0.8376
# Epoch 81/120
# 450/450 [==============================] - 62s 138ms/step - loss: 0.0131 - accuracy: 0.9964 - val_loss: 1.1255 - val_accuracy: 0.8356
# Epoch 82/120
# 450/450 [==============================] - 62s 138ms/step - loss: 0.0190 - accuracy: 0.9941 - val_loss: 1.1503 - val_accuracy: 0.8352
# Epoch 83/120
# 450/450 [==============================] - 62s 138ms/step - loss: 0.0140 - accuracy: 0.9952 - val_loss: 1.2518 - val_accuracy: 0.8168
# Epoch 84/120
# 450/450 [==============================] - 62s 138ms/step - loss: 0.0146 - accuracy: 0.9951 - val_loss: 1.0963 - val_accuracy: 0.8412
# Epoch 85/120
# 450/450 [==============================] - 62s 138ms/step - loss: 0.0144 - accuracy: 0.9951 - val_loss: 1.0559 - val_accuracy: 0.8406
# Epoch 86/120
# 450/450 [==============================] - 62s 138ms/step - loss: 0.0117 - accuracy: 0.9961 - val_loss: 1.0930 - val_accuracy: 0.8306
# Epoch 87/120
# 450/450 [==============================] - 62s 138ms/step - loss: 0.0161 - accuracy: 0.9947 - val_loss: 1.0894 - val_accuracy: 0.8334
# Epoch 88/120
# 450/450 [==============================] - 62s 138ms/step - loss: 0.0120 - accuracy: 0.9962 - val_loss: 1.0883 - val_accuracy: 0.8384
# Epoch 89/120
# 450/450 [==============================] - 62s 138ms/step - loss: 0.0144 - accuracy: 0.9958 - val_loss: 0.9609 - val_accuracy: 0.8438
# Epoch 90/120
# 450/450 [==============================] - 62s 138ms/step - loss: 0.0100 - accuracy: 0.9967 - val_loss: 1.0705 - val_accuracy: 0.8280
# Epoch 91/120
# 450/450 [==============================] - 62s 139ms/step - loss: 0.0159 - accuracy: 0.9950 - val_loss: 0.9998 - val_accuracy: 0.8346
# Epoch 92/120
# 450/450 [==============================] - 62s 138ms/step - loss: 0.0149 - accuracy: 0.9950 - val_loss: 1.0711 - val_accuracy: 0.8324
# Epoch 93/120
# 450/450 [==============================] - 63s 139ms/step - loss: 0.0109 - accuracy: 0.9967 - val_loss: 1.0552 - val_accuracy: 0.8398
# Epoch 94/120
# 450/450 [==============================] - 62s 139ms/step - loss: 0.0155 - accuracy: 0.9949 - val_loss: 0.9504 - val_accuracy: 0.8358
# Epoch 95/120
# 450/450 [==============================] - 62s 139ms/step - loss: 0.0130 - accuracy: 0.9956 - val_loss: 1.1132 - val_accuracy: 0.8362
# Epoch 96/120
# 450/450 [==============================] - 62s 139ms/step - loss: 0.0151 - accuracy: 0.9951 - val_loss: 1.0515 - val_accuracy: 0.8390
# Epoch 97/120
# 450/450 [==============================] - 62s 139ms/step - loss: 0.0081 - accuracy: 0.9971 - val_loss: 1.1130 - val_accuracy: 0.8378
# Epoch 98/120
# 450/450 [==============================] - 62s 139ms/step - loss: 0.0130 - accuracy: 0.9960 - val_loss: 0.9397 - val_accuracy: 0.8424
# Epoch 99/120
# 450/450 [==============================] - 62s 138ms/step - loss: 0.0074 - accuracy: 0.9975 - val_loss: 1.1048 - val_accuracy: 0.8444
# Epoch 100/120
# 450/450 [==============================] - 62s 138ms/step - loss: 0.0164 - accuracy: 0.9951 - val_loss: 0.9892 - val_accuracy: 0.8462
# Epoch 101/120
# 450/450 [==============================] - 62s 139ms/step - loss: 0.0136 - accuracy: 0.9955 - val_loss: 1.0964 - val_accuracy: 0.8408
# Epoch 102/120
# 450/450 [==============================] - 62s 139ms/step - loss: 0.0122 - accuracy: 0.9961 - val_loss: 1.0470 - val_accuracy: 0.8330
# Epoch 103/120
# 450/450 [==============================] - 62s 139ms/step - loss: 0.0093 - accuracy: 0.9969 - val_loss: 0.9826 - val_accuracy: 0.8404
# Epoch 104/120
# 450/450 [==============================] - 62s 139ms/step - loss: 0.0114 - accuracy: 0.9964 - val_loss: 1.1734 - val_accuracy: 0.8216
# Epoch 105/120
# 450/450 [==============================] - 62s 139ms/step - loss: 0.0140 - accuracy: 0.9956 - val_loss: 1.0648 - val_accuracy: 0.8396
# Epoch 106/120
# 450/450 [==============================] - 62s 139ms/step - loss: 0.0110 - accuracy: 0.9965 - val_loss: 1.1356 - val_accuracy: 0.8418
# Epoch 107/120
# 450/450 [==============================] - 62s 139ms/step - loss: 0.0125 - accuracy: 0.9959 - val_loss: 1.0446 - val_accuracy: 0.8416
# Epoch 108/120
# 450/450 [==============================] - 62s 139ms/step - loss: 0.0086 - accuracy: 0.9973 - val_loss: 1.1198 - val_accuracy: 0.8348
# Epoch 109/120
# 450/450 [==============================] - 62s 138ms/step - loss: 0.0121 - accuracy: 0.9965 - val_loss: 1.0761 - val_accuracy: 0.8406
# Epoch 110/120
# 450/450 [==============================] - 62s 138ms/step - loss: 0.0115 - accuracy: 0.9966 - val_loss: 1.0312 - val_accuracy: 0.8442
# Epoch 111/120
# 450/450 [==============================] - 62s 138ms/step - loss: 0.0100 - accuracy: 0.9968 - val_loss: 1.0438 - val_accuracy: 0.8416
# Epoch 112/120
# 450/450 [==============================] - 62s 138ms/step - loss: 0.0145 - accuracy: 0.9952 - val_loss: 1.1103 - val_accuracy: 0.8360
# Epoch 113/120
# 450/450 [==============================] - 62s 138ms/step - loss: 0.0121 - accuracy: 0.9961 - val_loss: 0.9021 - val_accuracy: 0.8384
# Epoch 114/120
# 450/450 [==============================] - 62s 138ms/step - loss: 0.0107 - accuracy: 0.9966 - val_loss: 1.2042 - val_accuracy: 0.8338
# Epoch 115/120
# 450/450 [==============================] - 62s 138ms/step - loss: 0.0100 - accuracy: 0.9969 - val_loss: 1.0098 - val_accuracy: 0.8498
# Epoch 116/120
# 450/450 [==============================] - 62s 138ms/step - loss: 0.0114 - accuracy: 0.9968 - val_loss: 1.0840 - val_accuracy: 0.8358
# Epoch 117/120
# 450/450 [==============================] - 62s 138ms/step - loss: 0.0123 - accuracy: 0.9959 - val_loss: 1.0759 - val_accuracy: 0.8366
# Epoch 118/120
# 450/450 [==============================] - 62s 138ms/step - loss: 0.0082 - accuracy: 0.9975 - val_loss: 1.0588 - val_accuracy: 0.8378
# Epoch 119/120
# 450/450 [==============================] - 62s 138ms/step - loss: 0.0138 - accuracy: 0.9954 - val_loss: 1.0923 - val_accuracy: 0.8406
# Epoch 120/120
# 450/450 [==============================] - 62s 139ms/step - loss: 0.0096 - accuracy: 0.9972 - val_loss: 1.0151 - val_accuracy: 0.8442

# %% [markdown]
# **Saving the Model, History and Time**

# %%
model.save('WideResNet.h5')

# %%
np.save('WideResNet_history.npy', history.history)

# %%
with open('WideResNet_time.pkl', 'wb') as f:
    pickle.dump(round(end - start), f)

# %% [markdown]
# **Training Analysis**

# %%
with open('WideResNet_time.pkl', 'rb') as f: 
    time_loaded = pickle.load(f)
print("Time taken for training (1 epoch): ", time_loaded, "seconds")
# Out:
# Time taken for training (1 epoch):  64 seconds

# %%
history_loaded = np.load('WideResNet_history.npy', allow_pickle = 'TRUE').item()

plt.plot(history_loaded['accuracy'])
plt.plot(history_loaded['val_accuracy'])
plt.title('WideResNet Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['train', 'val'], loc = 'upper left')
plt.show()

plt.plot(history_loaded['loss'])
plt.plot(history_loaded['val_loss'])
plt.title('WideResNet Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['train', 'val'], loc='upper right')
plt.show()

# %% [markdown]
# **Testing Analysis**

# %%
model_loaded = load_model('WideResNet.h5')
y_pred = model_loaded.predict(x_test)

# %%
def convert(y):
  return [class_names[np.argmax(i)] for i in y]

y_pred_class = convert(y_pred)
y_true_class = convert(y_test)

# %%
print("********** Accuracy **********\n\n", accuracy_score(y_true_class, y_pred_class) * 100, "%")
print("\n\n********** Classification Report ***********\n\n", classification_report(y_true_class, y_pred_class))
print("\n\n********** Confusion Matrix ***********\n\n")
sns.heatmap(confusion_matrix(y_true_class, y_pred_class), annot = True, fmt = 'd', cmap = 'Blues', xticklabels = class_names, yticklabels = class_names)
plt.xlabel('Predicted Class')
plt.ylabel('True Class')
plt.title('WideResNet')
plt.show()
# Out:
# ********** Accuracy **********
#
#  84.34 %
#
#
# ********** Classification Report ***********
#
#                precision    recall  f1-score   support
#
#     airplane       0.86      0.86      0.86      1000
#   automobile       0.89      0.94      0.91      1000
#         bird       0.81      0.76      0.79      1000
#          cat       0.71      0.73      0.72      1000
#         deer       0.85      0.81      0.83      1000
#          dog       0.81      0.73      0.77      1000
#         frog       0.81      0.92      0.86      1000
#        horse       0.87      0.89      0.88      1000
#         ship       0.92      0.91      0.91      1000
#        truck       0.92      0.89      0.90      1000
#
#     accuracy                           0.84     10000
#    macro avg       0.84      0.84      0.84     10000
# weighted avg       0.84      0.84      0.84     10000
#
#
#
# ********** Confusion Matrix ***********
