# %% [markdown]
# **Loading the dataset**

# %%
from google.colab import drive
drive.mount('/content/gdrive')

# %cd gdrive/My Drive/Project

import cifar10

cifar10.data_path = "data/CIFAR-10/"
cifar10.maybe_download_and_extract()

class_names = cifar10.load_class_names()
images_train, cls_train, labels_train= cifar10.load_training_data()
images_test, cls_test, labels_test = cifar10.load_test_data()

x_train = images_train[0:45000]
y_train = labels_train[0:45000]


x_valid = images_train[45000:50000]
y_valid = labels_train[45000:50000]

x_test = images_test
y_test = labels_test
# Out:
# Mounted at /content/gdrive
# /content/gdrive/My Drive/Project
# Data has apparently already been downloaded and unpacked.
# Loading data: data/CIFAR-10/cifar-10-batches-py/batches.meta
# Loading data: data/CIFAR-10/cifar-10-batches-py/data_batch_1
# Loading data: data/CIFAR-10/cifar-10-batches-py/data_batch_2
# Loading data: data/CIFAR-10/cifar-10-batches-py/data_batch_3
# Loading data: data/CIFAR-10/cifar-10-batches-py/data_batch_4
# Loading data: data/CIFAR-10/cifar-10-batches-py/data_batch_5
# Loading data: data/CIFAR-10/cifar-10-batches-py/test_batch

# %% [markdown]
# **Import Statements**

# %%
from keras.models import Sequential, load_model
from keras.optimizers import Adam
from keras.initializers import glorot_uniform
from keras.layers import Conv2D, MaxPooling2D, Dropout, Dense, Flatten, BatchNormalization
from sklearn.metrics import classification_report, accuracy_score, confusion_matrix
import time
import pickle
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %% [markdown]
# **Building the Model**

# %%
def SequentialNet():
  model = Sequential()

  model.add(Conv2D(64, (3,3), activation = 'relu', padding = "same", input_shape = (32,32,3), kernel_initializer = glorot_uniform(seed = 0)))
  model.add(BatchNormalization())
  model.add(Conv2D(64, (3,3), activation = 'relu', padding = "same", kernel_initializer = glorot_uniform(seed = 0)))
  model.add(BatchNormalization())
  model.add(Conv2D(64, (3,3), activation = 'relu', padding = "same", kernel_initializer = glorot_uniform(seed = 0)))
  model.add(BatchNormalization())
  model.add(MaxPooling2D(pool_size = (2,2)))
  model.add(Dropout(0.25))

  model.add(Conv2D(128, (3,3), activation = 'relu', padding = "same", kernel_initializer = glorot_uniform(seed = 0)))
  model.add(BatchNormalization())
  model.add(Conv2D(128, (3,3), activation = 'relu', padding = "same", kernel_initializer = glorot_uniform(seed = 0)))
  model.add(BatchNormalization())
  model.add(Conv2D(128, (3,3), activation = 'relu', padding = "same", kernel_initializer = glorot_uniform(seed = 0)))
  model.add(BatchNormalization())
  model.add(MaxPooling2D(pool_size = (2,2)))
  model.add(Dropout(0.25))

  model.add(Conv2D(256, (3,3), activation = 'relu', padding = "same", kernel_initializer = glorot_uniform(seed = 0)))
  model.add(BatchNormalization())
  model.add(Conv2D(256, (3,3), activation = 'relu', padding = "same", kernel_initializer = glorot_uniform(seed = 0)))
  model.add(BatchNormalization())
  model.add(Conv2D(256, (3,3), activation = 'relu', padding = "same", kernel_initializer = glorot_uniform(seed = 0)))
  model.add(BatchNormalization())
  model.add(MaxPooling2D(pool_size = (2,2)))
  model.add(Dropout(0.25))

  model.add(Flatten())

  model.add(Dense(1024, activation = 'relu', kernel_initializer = glorot_uniform(seed = 0)))
  model.add(Dropout(0.5))
  model.add(Dense(1024, activation = 'relu', kernel_initializer = glorot_uniform(seed = 0)))
  model.add(Dropout(0.5))
  model.add(Dense(1024, activation = 'relu', kernel_initializer = glorot_uniform(seed = 0)))
  model.add(Dropout(0.7))
  model.add(Dense(1024, activation = 'relu', kernel_initializer = glorot_uniform(seed = 0)))
  model.add(Dropout(0.8))

  model.add(Dense(10, activation = 'softmax'))

  return model

# %%
model = SequentialNet()
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 32, 32, 64)        1792
# _________________________________________________________________
# batch_normalization (BatchNo (None, 32, 32, 64)        256
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 32, 32, 64)        36928
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 32, 32, 64)        256
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 32, 32, 64)        36928
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 32, 32, 64)        256
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 16, 16, 64)        0
# _________________________________________________________________
# dropout (Dropout)            (None, 16, 16, 64)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 16, 16, 128)       73856
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 16, 16, 128)       512
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 16, 16, 128)       147584
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 16, 16, 128)       512
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 16, 16, 128)       147584
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 16, 16, 128)       512
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 8, 8, 128)         0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 8, 8, 128)         0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 8, 8, 256)         295168
# _________________________________________________________________
# batch_normalization_6 (Batch (None, 8, 8, 256)         1024
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 8, 8, 256)         590080
# _________________________________________________________________
# batch_normalization_7 (Batch (None, 8, 8, 256)         1024
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 8, 8, 256)         590080
# _________________________________________________________________
# batch_normalization_8 (Batch (None, 8, 8, 256)         1024
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 4, 4, 256)         0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 4, 4, 256)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 4096)              0
# _________________________________________________________________
# dense (Dense)                (None, 1024)              4195328
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 1024)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1024)              1049600
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 1024)              0
# _________________________________________________________________
# dense_2 (Dense)              (None, 1024)              1049600
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 1024)              0
# _________________________________________________________________
# dense_3 (Dense)              (None, 1024)              1049600
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 1024)              0
# _________________________________________________________________
# dense_4 (Dense)              (None, 10)                10250
# =================================================================
# Total params: 9,279,754
# Trainable params: 9,277,066
# Non-trainable params: 2,688
# _________________________________________________________________

# %% [markdown]
# **Training the Model**

# %%
model = SequentialNet()
model.compile(loss = 'categorical_crossentropy', optimizer = Adam(learning_rate = 1.0e-4), metrics = ['accuracy'])
start = time.time()
model.fit(x_train, y_train, epochs = 1, batch_size = 100, validation_data = (x_valid, y_valid))
end = time.time()
# Out:
#   1/450 [..............................] - ETA: 0s - loss: 8.9318 - accuracy: 0.1800WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0130s vs `on_train_batch_end` time: 0.0246s). Check your callbacks.
# 449/450 [============================>.] - ETA: 0s - loss: 2.7552 - accuracy: 0.0985WARNING:tensorflow:Callbacks method `on_test_batch_end` is slow compared to the batch time (batch time: 0.0026s vs `on_test_batch_end` time: 0.0083s). Check your callbacks.
# 450/450 [==============================] - 17s 39ms/step - loss: 2.7543 - accuracy: 0.0984 - val_loss: 2.3004 - val_accuracy: 0.1040

# %%
model = SequentialNet()
model.compile(loss = 'categorical_crossentropy', optimizer = Adam(learning_rate = 1.0e-4), metrics = ['accuracy'])
history = model.fit(x_train, y_train,epochs = 120, batch_size = 100, validation_data = (x_valid, y_valid))
# Out:
# Epoch 1/120
#   1/450 [..............................] - ETA: 12s - loss: 11.2192 - accuracy: 0.0600WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0071s vs `on_train_batch_end` time: 0.0278s). Check your callbacks.
# 449/450 [============================>.] - ETA: 0s - loss: 2.7565 - accuracy: 0.1031WARNING:tensorflow:Callbacks method `on_test_batch_end` is slow compared to the batch time (batch time: 0.0027s vs `on_test_batch_end` time: 0.0085s). Check your callbacks.
# 450/450 [==============================] - 18s 39ms/step - loss: 2.7555 - accuracy: 0.1032 - val_loss: 2.2979 - val_accuracy: 0.1160
# Epoch 2/120
# 450/450 [==============================] - 18s 40ms/step - loss: 2.3107 - accuracy: 0.1015 - val_loss: 2.2984 - val_accuracy: 0.1078
# Epoch 3/120
# 450/450 [==============================] - 18s 40ms/step - loss: 2.2831 - accuracy: 0.1245 - val_loss: 2.2077 - val_accuracy: 0.1328
# Epoch 4/120
# 450/450 [==============================] - 18s 40ms/step - loss: 2.2109 - accuracy: 0.1687 - val_loss: 2.1279 - val_accuracy: 0.1632
# Epoch 5/120
# 450/450 [==============================] - 18s 39ms/step - loss: 2.1500 - accuracy: 0.1868 - val_loss: 2.0471 - val_accuracy: 0.2298
# Epoch 6/120
# 450/450 [==============================] - 18s 39ms/step - loss: 2.0619 - accuracy: 0.2220 - val_loss: 1.9807 - val_accuracy: 0.2714
# Epoch 7/120
# 450/450 [==============================] - 18s 40ms/step - loss: 1.9725 - accuracy: 0.2551 - val_loss: 1.9497 - val_accuracy: 0.2866
# Epoch 8/120
# 450/450 [==============================] - 18s 40ms/step - loss: 1.8818 - accuracy: 0.2833 - val_loss: 1.7847 - val_accuracy: 0.3426
# Epoch 9/120
# 450/450 [==============================] - 18s 40ms/step - loss: 1.7852 - accuracy: 0.3204 - val_loss: 1.6540 - val_accuracy: 0.3740
# Epoch 10/120
# 450/450 [==============================] - 18s 39ms/step - loss: 1.6714 - accuracy: 0.3500 - val_loss: 1.5560 - val_accuracy: 0.3872
# Epoch 11/120
# 450/450 [==============================] - 18s 39ms/step - loss: 1.5893 - accuracy: 0.3759 - val_loss: 1.4690 - val_accuracy: 0.4222
# Epoch 12/120
# 450/450 [==============================] - 18s 39ms/step - loss: 1.5197 - accuracy: 0.4017 - val_loss: 1.4016 - val_accuracy: 0.4714
# Epoch 13/120
# 450/450 [==============================] - 18s 39ms/step - loss: 1.4296 - accuracy: 0.4458 - val_loss: 1.2910 - val_accuracy: 0.5164
# Epoch 14/120
# 450/450 [==============================] - 18s 39ms/step - loss: 1.3377 - accuracy: 0.4859 - val_loss: 1.2206 - val_accuracy: 0.5448
120
# 450/450 [==============================] - 18s 39ms/step - loss: 0.0540 - accuracy: 0.9855 - val_loss: 0.5436 - val_accuracy: 0.8674
# Epoch 111/120
# 450/450 [==============================] - 18s 40ms/step - loss: 0.0502 - accuracy: 0.9864 - val_loss: 0.5485 - val_accuracy: 0.8712
# Epoch 112/120
# 450/450 [==============================] - 18s 39ms/step - loss: 0.0500 - accuracy: 0.9860 - val_loss: 0.5936 - val_accuracy: 0.8606
# Epoch 113/120
# 450/450 [==============================] - 18s 39ms/step - loss: 0.0393 - accuracy: 0.9890 - val_loss: 0.6288 - val_accuracy: 0.8652
# Epoch 114/120
# 450/450 [==============================] - 18s 40ms/step - loss: 0.0464 - accuracy: 0.9879 - val_loss: 0.6364 - val_accuracy: 0.8650
# Epoch 115/120
# 450/450 [==============================] - 18s 39ms/step - loss: 0.0439 - accuracy: 0.9875 - val_loss: 0.5830 - val_accuracy: 0.8702
# Epoch 116/120
# 450/450 [==============================] - 18s 39ms/step - loss: 0.0485 - accuracy: 0.9873 - val_loss: 0.5812 - val_accuracy: 0.8716
# Epoch 117/120
# 450/450 [==============================] - 18s 40ms/step - loss: 0.0475 - accuracy: 0.9866 - val_loss: 0.5779 - val_accuracy: 0.8688
# Epoch 118/120
# 450/450 [==============================] - 18s 40ms/step - loss: 0.0511 - accuracy: 0.9864 - val_loss: 0.5812 - val_accuracy: 0.8644
# Epoch 119/120
# 450/450 [==============================] - 18s 40ms/step - loss: 0.0441 - accuracy: 0.9887 - val_loss: 0.6042 - val_accuracy: 0.8628
# Epoch 120/120
# 450/450 [==============================] - 18s 39ms/step - loss: 0.0419 - accuracy: 0.9881 - val_loss: 0.5688 - val_accuracy: 0.8724

# %% [markdown]
# **Saving the Model, History and Time**

# %%
model.save('SequentialNet.h5')

# %%
np.save('SequentialNet_history.npy', history.history)

# %%
with open('SequentialNet_time.pkl', 'wb') as f:
    pickle.dump(round(end - start), f)

# %% [markdown]
# **Training Analysis**

# %%
with open('SequentialNet_time.pkl', 'rb') as f: 
    time_loaded = pickle.load(f)
print("Time taken for training (1 epoch): ", time_loaded, "seconds")
# Out:
# Time taken for training (1 epoch):  26 seconds

# %%
history_loaded = np.load('SequentialNet_history.npy', allow_pickle = 'TRUE').item()

plt.plot(history_loaded['accuracy'])
plt.plot(history_loaded['val_accuracy'])
plt.title('SequentialNet Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['train', 'val'], loc = 'upper left')
plt.show()

plt.plot(history_loaded['loss'])
plt.plot(history_loaded['val_loss'])
plt.title('SequentialNet Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['train', 'val'], loc='upper right')
plt.show()

# %% [markdown]
# **Testing Analysis**

# %%
model_loaded = load_model('SequentialNet.h5')
y_pred = model_loaded.predict(x_test)

# %%
def convert(y):
  return [class_names[np.argmax(i)] for i in y]

y_pred_class = convert(y_pred)
y_true_class = convert(y_test)

# %%
print("********** Accuracy **********\n\n", accuracy_score(y_true_class, y_pred_class) * 100, "%")
print("\n\n********** Classification Report ***********\n\n", classification_report(y_true_class, y_pred_class))
print("\n\n********** Confusion Matrix ***********\n\n")
sns.heatmap(confusion_matrix(y_true_class, y_pred_class), annot = True, fmt = 'd', cmap = 'Blues', xticklabels = class_names, yticklabels = class_names)
plt.xlabel('Predicted Class')
plt.ylabel('True Class')
plt.title('SequentialNet')
plt.show()
# Out:
# ********** Accuracy **********
#
#  86.82 %
#
#
# ********** Classification Report ***********
#
#                precision    recall  f1-score   support
#
#     airplane       0.90      0.87      0.89      1000
#   automobile       0.86      0.94      0.90      1000
#         bird       0.83      0.81      0.82      1000
#          cat       0.78      0.73      0.75      1000
#         deer       0.84      0.88      0.86      1000
#          dog       0.81      0.79      0.80      1000
#         frog       0.90      0.92      0.91      1000
#        horse       0.93      0.90      0.91      1000
#         ship       0.93      0.92      0.93      1000
#        truck       0.91      0.92      0.91      1000
#
#     accuracy                           0.87     10000
#    macro avg       0.87      0.87      0.87     10000
# weighted avg       0.87      0.87      0.87     10000
#
#
#
# ********** Confusion Matrix ***********
